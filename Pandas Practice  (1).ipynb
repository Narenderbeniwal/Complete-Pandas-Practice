# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",None)

# %%
df = pd.DataFrame({
    "a":[4,5,6,7,8,9],
    "b":[7,8,9,10,11,12],
    "c":[10,12,14,15,16,18]},
    index = [1,2,3,4,5,6]
)

# %%
df
# Out:
#    a   b   c
# 1  4   7  10
# 2  5   8  12
# 3  6   9  14
# 4  7  10  15
# 5  8  11  16
# 6  9  12  18

# %%
df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index = pd.MultiIndex.from_tuples(
[('d',1),('d',2),('e',2)],
names=['n','v']))

# %%
df
# Out:
#      0  1   2
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
df
# Out:
#      0  1   2
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
df = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = pd.MultiIndex.from_tuples(
[('d',1),('d',2),('e',2)],
names=['n','v']))

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
df = (pd.melt(df)
.rename(columns={
'variable' : 'var',
'value' : 'val'})
.query('val >= 200')
)

# %%
df
# Out:
# Empty DataFrame
# Columns: [var, val]
# Index: []

# %%
df1 = pd.read_csv("/Users/narenderbeniwal/Downloads/stack-overflow-developer-survey-2021/survey_results_public.csv")
pd.set_option("display.max_columns", None)

# %%
df1
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.shape
# Out:
# (0, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var     0 non-null      object
#  1   val     0 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 0.0+ bytes

# %%
schema_df = pd.read_csv("/Users/narenderbeniwal/Downloads/stack-overflow-developer-survey-2021/survey_results_schema.csv")

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df.tail(5)
# Out:
#        qid          qname                                           question  \
# 43  QID124  Accessibility  Which of the following describe you, if any? P...
# 44  QID125   MentalHealth  Which of the following describe you, if any? P...
# 45  QID131             S6  <span style="font-size:22px;"><strong>Final Qu...
# 46  QID132   SurveyLength  How do you feel about the length of the survey...
# 47  QID133     SurveyEase  How easy or difficult was this survey to compl...
#
#     force_resp type selector
# 43       False   MC     MAVR
# 44       False   MC     MAVR
# 45       False   DB       TB
# 46       False   MC     MAVR
# 47       False   MC     MAVR

# %% [markdown]
# # DataFrame and Series Basics - Selecting Rows and Columns

# %%
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}

# %%
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
people['first']
# Out:
# ['Corey', 'Jane', 'John']

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df[['last','email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[[0,1],[2,1]]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %%
df.loc[[0,1], ['email','last']]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %% [markdown]
# ## Now working the stack overflow dataset

# %%
df1.shape
# Out:
# (83439, 48)

# %%
df1.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df1['NEWSOSites'].value_counts()
# Out:
# Stack Overflow;Stack Exchange                                                                                                54658
# Stack Overflow                                                                                                               23473
# Stack Overflow;Stack Exchange;Stack Overflow for Teams (private knowledge sharing & collaboration platform for companies)     3099
# I have never visited Stack Overflow or the Stack Exchange network                                                              750
# Stack Overflow;Stack Overflow for Teams (private knowledge sharing & collaboration platform for companies)                     671
# Stack Exchange                                                                                                                 257
# Stack Overflow for Teams (private knowledge sharing & collaboration platform for companies)                                    246
# ...

# %%
df1['NEWSOSites']
# Out:
# 0                                           Stack Overflow
# 1                                           Stack Overflow
# 2                            Stack Overflow;Stack Exchange
# 3                                           Stack Overflow
# 4                            Stack Overflow;Stack Exchange
#                                ...
# 83434                        Stack Overflow;Stack Exchange
# 83435                        Stack Overflow;Stack Exchange
# 83436                        Stack Overflow;Stack Exchange
# 83437                                       Stack Overflow
# 83438    Stack Overflow;Stack Exchange;Stack Overflow f...
# Name: NEWSOSites, Length: 83439, dtype: object

# %%
#df1.loc[[0,1,2,67],'NEWSOSites']

# %%
df1.loc[0:9,'NEWSOSites':'Gender']
# Out:
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 5  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 6                 Stack Overflow   Daily or almost daily       Yes
# 7  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 8  Stack Overflow;Stack Exchange    A few times per week       Yes
# 9  Stack Overflow;Stack Exchange  Multiple times per day       Yes
#
#                                           SOPartFreq           SOComm  \
# 0                    A few times per month or weekly  Yes, definitely
# 1                              Daily or almost daily  Yes, definitely
# ...

# %% [markdown]
# ## Indexes - How to Set, Reset, and Use Indexes

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.set_index('email',inplace=True)

# %%
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
df.loc['JaneDoe@email.com']
# Out:
# first    Jane
# last      Doe
# Name: JaneDoe@email.com, dtype: object

# %%
df.loc['JohnDoe@email.com']
# Out:
# first    John
# last      Doe
# Name: JohnDoe@email.com, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %% [markdown]
# ## Now working the stack overflow dataset

# %%
df1.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df1 = pd.read_csv("/Users/narenderbeniwal/Downloads/stack-overflow-developer-survey-2021/survey_results_public.csv",index_col = 'ResponseId')

# %%
df1
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df1.loc[[1,4]]
# Out:
#                                 MainBranch  \
# ResponseId
# 1           I am a developer by profession
# 4           I am a developer by profession
#
#                                                    Employment   Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...  Slovakia
# 4                                          Employed full-time   Austria
#
#            US_State UK_Country  \
# ResponseId
# 1               NaN        NaN
# 4               NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# 4             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# ...

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df['question']
# Out:
# 0     <div><span style="font-size:19px;"><strong>Hel...
# 1                                     Browser Meta Info
# 2     <span style="font-size:22px; font-family: aria...
# 3     Which of the following options best describes ...
# 4     Which of the following best describes your cur...
# 5     Where do you live? <span style="font-weight: b...
# 6     <p>In which state or territory of the USA do y...
# 7     In which part of the United Kingdom do you liv...
# 8     <span style="font-size:22px; font-family: aria...
# 9     Which of the following best describes the high...
# 10    At what age did you write your first line of c...
# 11    How did you learn to code? Select all that apply.
# 12    Including any education, how many years have y...
# 13    NOT including education, how many years have y...
# 14    Which of the following describes your current ...
# 15    Approximately how many people are employed by ...
# 16    Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df = pd.read_csv("/Users/narenderbeniwal/Downloads/stack-overflow-developer-survey-2021/survey_results_schema.csv", index_col = "qname")

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
schema_df.loc['S3','question']
# Out:
# '<span style="font-size:22px; font-family: arial,helvetica,sans-serif; font-weight: 700;">Tech and tech culture</span><br>\n<br>\n\n<p><span style="font-size:16px; font-family:arial,helvetica,sans-serif;">The next set of questions will focus on technology and tech culture.<br>\n<br>\nMost questions in this section are optional. Required questions are noted with *.</span></p>'

# %%
schema_df.sort_index(ascending=True)
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %% [markdown]
# ## Filtering - Using Conditionals to Filter Rows and Columns

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt = (df['last'] == 'Doe')

# %%
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
df.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df['last']=='Doe')& (df['first']=='John')

# %%
df.loc[filt]
# Out:
#                email first last
# 2  JohnDoe@email.com  John  Doe

# %%
filt = (df['last']=='Schafer')| (df['first']=='John')

# %%
df.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %% [markdown]
# ## Now working the stack overflow dataset

# %%
df1
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df1.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
high_salary = (df1['ConvertedCompYearly']>70000)

# %%
high_salary
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 83435     True
# 83436    False
# 83437     True
# 83438     True
# 83439    False
# Name: ConvertedCompYearly, Length: 83439, dtype: bool

# %%
df1.loc[high_salary, ['Employment','Country','ConvertedCompYearly']]
# Out:
#                      Employment                   Country  ConvertedCompYearly
# ResponseId
# 13           Employed full-time                   Germany              77290.0
# 19          I prefer not to say                 Singapore             160932.0
# 25           Employed full-time                   Germany              77831.0
# 27           Employed full-time               Switzerland              81319.0
# 32           Employed full-time                    Israel             122580.0
# ...                         ...                       ...                  ...
# 83431        Employed full-time  United States of America             125000.0
# 83433        Employed full-time                    Canada              80169.0
# 83435        Employed full-time  United States of America             160500.0
# 83437        Employed full-time  United States of America              90000.0
# 83438        Employed full-time                    Canada             816816.0
#
# ...

# %%
countries = ['Singapore','United States of America','Germany','Canada', 'India']
filt = df1['Country'].isin(countries)

# %%
df1.loc[filt,['Employment','Country','ConvertedCompYearly']]
# Out:
#                      Employment                   Country  ConvertedCompYearly
# ResponseId
# 6            Student, part-time  United States of America                  NaN
# 7           I prefer not to say  United States of America                  NaN
# 9            Employed part-time                     India                  NaN
# 13           Employed full-time                   Germany              77290.0
# 16           Student, full-time  United States of America                  NaN
# ...                         ...                       ...                  ...
# 83431        Employed full-time  United States of America             125000.0
# 83433        Employed full-time                    Canada              80169.0
# 83435        Employed full-time  United States of America             160500.0
# 83437        Employed full-time  United States of America              90000.0
# 83438        Employed full-time                    Canada             816816.0
#
# ...

# %%
filt = df1['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df1['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                    JavaScript;Python
# 3                             Assembly;C;Python;R;Rust
# 4                                JavaScript;TypeScript
# 5                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83435                               Clojure;Kotlin;SQL
# 83436                                              NaN
# 83437                               Groovy;Java;Python
# 83438             Bash/Shell;JavaScript;Node.js;Python
# 83439           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
df1
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %% [markdown]
# ## Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
df.columns = ['email','first_name','last_name']

# %%
df
# Out:
#                      email first_name last_name
# 0  CoreyMSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@email.com       Jane       Doe
# 2        JohnDoe@email.com       John       Doe

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#                      EMAIL FIRST_NAME LAST_NAME
# 0  CoreyMSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@email.com       Jane       Doe
# 2        JohnDoe@email.com       John       Doe

# %%
df.columns = df.columns.str.replace('_','')

# %%
df
# Out:
#                      EMAIL FIRSTNAME LASTNAME
# 0  CoreyMSchafer@gmail.com     Corey  Schafer
# 1        JaneDoe@email.com      Jane      Doe
# 2        JohnDoe@email.com      John      Doe

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#                      email firstname lastname
# 0  CoreyMSchafer@gmail.com     Corey  Schafer
# 1        JaneDoe@email.com      Jane      Doe
# 2        JohnDoe@email.com      John      Doe

# %%
df.columns = df.columns.str.replace('_','')

# %%
df
# Out:
#                      email firstname lastname
# 0  CoreyMSchafer@gmail.com     Corey  Schafer
# 1        JaneDoe@email.com      Jane      Doe
# 2        JohnDoe@email.com      John      Doe

# %%
df.rename(columns={'firstname':'first', 'lastname':'last'}, inplace=True)

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df.loc[2] = ['John','Smith','JohnDoe@email.com']

# %%
df
# Out:
#                      email  first               last
# 0  CoreyMSchafer@gmail.com  Corey            Schafer
# 1        JaneDoe@email.com   Jane                Doe
# 2                     John  Smith  JohnDoe@email.com

# %%
df.loc[2,['last','email']] = ['Doe','JohnDoe@email.com']

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com  Smith      Doe

# %%
df.loc[2, 'last'] = 'Smith'

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com  Smith    Smith

# %%
df.at[2,'last'] = 'Doe'

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com  Smith      Doe

# %%
filt = (df['email']=='JohnDoe@email.com')
df[filt]['last'] = 'Smith'
# Out:
# /var/folders/12/9_hj00mj65v4tgx35t4t6c280000gn/T/ipykernel_1909/1777826079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['last'] = 'Smith'

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com  Smith      Doe

# %%
filt = (df['email']=='JohnDoe@email.com')
df.loc[filt,'last'] = 'Smith'

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com  Smith    Smith

# %%
df['email'] = df['email'].str.lower()

# %%
df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com  Smith    Smith

# %% [markdown]
# ## Four Importent Methods
# ### 1. Apply
# ### 2. map
# ### 3. Applymap
# ### 4. replace

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df['email'] = df['email'].apply(update_email)

# %%
df
# Out:
#                      email  first     last
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@EMAIL.COM   Jane      Doe
# 2        JOHNDOE@EMAIL.COM  Smith    Smith

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com  Smith    Smith

# %%
df.apply(len)
# Out:
# email    3
# first    3
# last     3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(len, axis = 'columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: object

# %%
df.apply(lambda x:x.min())
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: object

# %%
df.applymap(len)
# Out:
#    email  first  last
# 0     23      5     7
# 1     17      4     3
# 2     17      5     5

# %%
df.applymap(str.lower)
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  corey  schafer
# 1        janedoe@email.com   jane      doe
# 2        johndoe@email.com  smith    smith

# %%
df['first'].map({'Corey':'Chris', 'jane':'mary'})
# Out:
# 0    Chris
# 1      NaN
# 2      NaN
# Name: first, dtype: object

# %%
df['first'] = df['first'].replace({'Corey':'Chris', 'jane':'mary'})

# %%
df['first']
# Out:
# 0    Chris
# 1     Jane
# 2    Smith
# Name: first, dtype: object

# %% [markdown]
# ## Now working the stack overflow dataset

# %%
df1.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df1.rename(columns = {'ConvertedCompYearly': 'SalaryUSD'}, inplace=True)

# %%
df1
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df1['SalaryUSD']
# Out:
# ResponseId
# 1         62268.0
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
#            ...
# 83435    160500.0
# 83436      3960.0
# 83437     90000.0
# 83438    816816.0
# 83439     21168.0
# Name: SalaryUSD, Length: 83439, dtype: float64

# %%
df1['OpSys']
# Out:
# ResponseId
# 1              MacOS
# 2            Windows
# 3              MacOS
# 4            Windows
# 5        Linux-based
#             ...
# 83435          MacOS
# 83436    Linux-based
# 83437        Windows
# 83438          MacOS
# 83439    Linux-based
# Name: OpSys, Length: 83439, dtype: object

# %%
df1['OpSys'].map({'MacOS':True, 'Windows':False,'Linux-based':'Good'})
# Out:
# ResponseId
# 1         True
# 2        False
# 3         True
# 4        False
# 5         Good
#          ...
# 83435     True
# 83436     Good
# 83437    False
# 83438     True
# 83439     Good
# Name: OpSys, Length: 83439, dtype: object

# %%
df1['OpSys'] = df1['OpSys'].map({'MacOS':True, 'Windows':False,'Linux-based':'Good'})

# %%
df1
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Chris  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com  Smith    Smith

# %% [markdown]
# ## Add/Remove Rows and Columns From DataFrames

# %%
df['first'] + ' '+ df['last']
# Out:
# 0    Chris Schafer
# 1         Jane Doe
# 2      Smith Smith
# dtype: object

# %%
df['full_name'] = df['first'] + ' '+ df['last']

# %%
df
# Out:
#                      email  first     last      full_name
# 0  coreymschafer@gmail.com  Chris  Schafer  Chris Schafer
# 1        janedoe@email.com   Jane      Doe       Jane Doe
# 2        johndoe@email.com  Smith    Smith    Smith Smith

# %%
df.drop(columns = ['first', 'last'], inplace=True)
df
# Out:
#                      email      full_name
# 0  coreymschafer@gmail.com  Chris Schafer
# 1        janedoe@email.com       Jane Doe
# 2        johndoe@email.com    Smith Smith

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Chris  Schafer
# 1   Jane      Doe
# 2  Smith    Smith

# %%
df[['first','last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe
# 2        johndoe@email.com    Smith Smith  Smith    Smith

# %%
df.append({'firsst':'Tony'}, ignore_index=True)
# Out:
#                      email      full_name  first     last firsst
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer    NaN
# 1        janedoe@email.com       Jane Doe   Jane      Doe    NaN
# 2        johndoe@email.com    Smith Smith  Smith    Smith    NaN
# 3                      NaN            NaN    NaN      NaN   Tony

# %%
people = {
    "first": ["Tony", "Steve"], 
    "last": ["Stark", "Rogers"], 
    "email": ["Ironman@gmail.com","Cap@avenge.com"]
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last              email
# 0   Tony   Stark  Ironman@gmail.com
# 1  Steve  Rogers     Cap@avenge.com

# %%
df.append(df2, ignore_index=True, sort = False)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe
# 2        johndoe@email.com    Smith Smith  Smith    Smith
# 3        Ironman@gmail.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df =df.append(df2, ignore_index=True, sort = False)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe
# 2        johndoe@email.com    Smith Smith  Smith    Smith
# 3        Ironman@gmail.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.drop(index=4)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe
# 2        johndoe@email.com    Smith Smith  Smith    Smith
# 3        Ironman@gmail.com            NaN   Tony    Stark

# %%
filt = df['last'] == 'Doe'
df.drop(index=df[filt].index)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2        johndoe@email.com    Smith Smith  Smith    Smith
# 3        Ironman@gmail.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe
# 2        johndoe@email.com    Smith Smith  Smith    Smith
# 3        Ironman@gmail.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.sort_values(by='last', ascending=False)
# Out:
#                      email      full_name  first     last
# 3        Ironman@gmail.com            NaN   Tony    Stark
# 2        johndoe@email.com    Smith Smith  Smith    Smith
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 4           Cap@avenge.com            NaN  Steve   Rogers
# 1        janedoe@email.com       Jane Doe   Jane      Doe

# %%
df.sort_values(by=['last','first'], ascending=False)
# Out:
#                      email      full_name  first     last
# 3        Ironman@gmail.com            NaN   Tony    Stark
# 2        johndoe@email.com    Smith Smith  Smith    Smith
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 4           Cap@avenge.com            NaN  Steve   Rogers
# 1        janedoe@email.com       Jane Doe   Jane      Doe

# %%
df.sort_values(by=['last','first'], ascending=[False, True],inplace=True)

# %%
df
# Out:
#                      email      full_name  first     last
# 3        Ironman@gmail.com            NaN   Tony    Stark
# 2        johndoe@email.com    Smith Smith  Smith    Smith
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 4           Cap@avenge.com            NaN  Steve   Rogers
# 1        janedoe@email.com       Jane Doe   Jane      Doe

# %%
df['last'].sort_values()
# Out:
# 1        Doe
# 4     Rogers
# 0    Schafer
# 2      Smith
# 3      Stark
# Name: last, dtype: object

# %% [markdown]
# ## Now working the stack overflow dataset

# %%
df1
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df1.sort_values(by=['Country','SalaryUSD'],ascending=[True, False], inplace=True)

# %%
df1
# Out:
#                                         MainBranch  \
# ResponseId
# 65400               I am a developer by profession
# 22667               I am a developer by profession
# 27199               I am a developer by profession
# 31087               I am a developer by profession
# 44641               I am a developer by profession
# ...                                            ...
# 75694       I am a student who is learning to code
# 76083               I am a developer by profession
# 79302       I am a student who is learning to code
# 80997                  I code primarily as a hobby
# 82407       I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 65400                                      Employed full-time  Afghanistan
# 22667       Independent contractor, freelancer, or self-em...  Afghanistan
# 27199       Independent contractor, freelancer, or self-em...  Afghanistan
# ...

# %%
df1[['Country','SalaryUSD']].head(500)
# Out:
#                 Country   SalaryUSD
# ResponseId
# 65400       Afghanistan  30468516.0
# 22667       Afghanistan    155496.0
# 27199       Afghanistan     51804.0
# 31087       Afghanistan     23964.0
# 44641       Afghanistan     15132.0
# ...                 ...         ...
# 60929         Argentina     25296.0
# 73682         Argentina     25296.0
# 43210         Argentina     25200.0
# 20319         Argentina     25000.0
# 56837         Argentina     24328.0
#
# [500 rows x 2 columns]

# %%
df1['SalaryUSD'].nlargest(10)
# Out:
# ResponseId
# 66911    45241312.0
# 65400    30468516.0
# 40587    21822250.0
# 28792    20000000.0
# 12701    19200000.0
# 9609     17500000.0
# 5306     15000000.0
# 12904    14411628.0
# 66489    12750000.0
# 7206     12500000.0
# Name: SalaryUSD, dtype: float64

# %%
df1.nsmallest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  \
# ResponseId
# 1925                           I am a developer by profession
# 24286                          I am a developer by profession
# 46465       I am not primarily a developer, but I write co...
# 15164                          I am a developer by profession
# 56791                          I am a developer by profession
# 22033                          I am a developer by profession
# 59044                          I am a developer by profession
# 22454                          I am a developer by profession
# 45142       I am not primarily a developer, but I write co...
# 53307                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1925                                       Employed full-time
# 24286       Independent contractor, freelancer, or self-em...
# 46465                                      Employed full-time
# ...

# %%
df1
# Out:
#                                         MainBranch  \
# ResponseId
# 65400               I am a developer by profession
# 22667               I am a developer by profession
# 27199               I am a developer by profession
# 31087               I am a developer by profession
# 44641               I am a developer by profession
# ...                                            ...
# 75694       I am a student who is learning to code
# 76083               I am a developer by profession
# 79302       I am a student who is learning to code
# 80997                  I code primarily as a hobby
# 82407       I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 65400                                      Employed full-time  Afghanistan
# 22667       Independent contractor, freelancer, or self-em...  Afghanistan
# 27199       Independent contractor, freelancer, or self-em...  Afghanistan
# ...

# %% [markdown]
# ## Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df1['SalaryUSD'].head(16)
# Out:
# ResponseId
# 65400    30468516.0
# 22667      155496.0
# 27199       51804.0
# 31087       23964.0
# 44641       15132.0
# 11378        9792.0
# 17487        5448.0
# 51429        4668.0
# 14883        4200.0
# 17121        3108.0
# 55151         100.0
# 2070            NaN
# 4545            NaN
# 5101            NaN
# 9565            NaN
# 10946           NaN
# Name: SalaryUSD, dtype: float64

# %%
df1['SalaryUSD'].median()
# Out:
# 56211.0

# %%
df1.median()
# Out:
# /var/folders/12/9_hj00mj65v4tgx35t4t6c280000gn/T/ipykernel_1909/2279417019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# CompTotal    67000.0
# SalaryUSD    56211.0
# dtype: float64

# %%
df1.describe()
# Out:
#           CompTotal     SalaryUSD
# count  4.718300e+04  4.684400e+04
# mean   2.119407e+69  1.184262e+05
# std    4.603702e+71  5.272944e+05
# min    0.000000e+00  1.000000e+00
# 25%    1.600000e+04  2.702500e+04
# 50%    6.700000e+04  5.621100e+04
# 75%    1.400000e+05  1.000000e+05
# max    1.000000e+74  4.524131e+07

# %%
df1['SalaryUSD'].count()
# Out:
# 46844

# %%
df1['Accessibility'].value_counts()
# Out:
# None of the above                                                                                                                                                                                           72725
# Prefer not to say                                                                                                                                                                                            1918
# I am blind / have difficulty seeing                                                                                                                                                                          1030
# Or, in your own words:                                                                                                                                                                                        842
# ...

# %%
df1['SurveyEase']
# Out:
# ResponseId
# 65400                     Difficult
# 22667                          Easy
# 27199                     Difficult
# 31087    Neither easy nor difficult
# 44641    Neither easy nor difficult
#                     ...
# 75694    Neither easy nor difficult
# 76083                          Easy
# 79302                           NaN
# 80997                          Easy
# 82407    Neither easy nor difficult
# Name: SurveyEase, Length: 83439, dtype: object

# %%
schema_df.loc['SurveyEase']
# Out:
# qid                                                      QID133
# question      How easy or difficult was this survey to compl...
# force_resp                                                False
# type                                                         MC
# selector                                                   MAVR
# Name: SurveyEase, dtype: object

# %%
df1['SurveyEase'].value_counts()
# Out:
# Easy                          63087
# Neither easy nor difficult    18091
# Difficult                       770
# Name: SurveyEase, dtype: int64

# %%
df1['SurveyEase'].value_counts(normalize=True)
# Out:
# Easy                          0.769842
# Neither easy nor difficult    0.220762
# Difficult                     0.009396
# Name: SurveyEase, dtype: float64

# %%
df1['Country']
# Out:
# ResponseId
# 65400    Afghanistan
# 22667    Afghanistan
# 27199    Afghanistan
# 31087    Afghanistan
# 44641    Afghanistan
#             ...
# 75694       Zimbabwe
# 76083       Zimbabwe
# 79302       Zimbabwe
# 80997       Zimbabwe
# 82407       Zimbabwe
# Name: Country, Length: 83439, dtype: object

# %%
df1['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Papua New Guinea                                            1
# Dominica                                                    1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_grp = df1.groupby(['Country'])

# %%
country_grp.get_group('United States of America')
# Out:
#                                                    MainBranch  \
# ResponseId
# 40587                          I am a developer by profession
# 9609        I am not primarily a developer, but I write co...
# 5306                           I am a developer by profession
# 66489                          I am a developer by profession
# 7206                           I am a developer by profession
# ...                                                       ...
# 83401                          I am a developer by profession
# 83413                          I am a developer by profession
# 83415                             I code primarily as a hobby
# 83427                          I am a developer by profession
# 83430                             I code primarily as a hobby
#
#                                                    Employment  \
# ResponseId
# 40587                                      Employed full-time
# 9609                                       Employed full-time
# ...

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch  \
# ResponseId
# 28792                          I am a developer by profession
# 12701                          I am a developer by profession
# 64388                          I am a developer by profession
# 12794                          I am a developer by profession
# 3641                           I am a developer by profession
# ...                                                       ...
# 83387                          I am a developer by profession
# 83398       I used to be a developer by profession, but no...
# 83407                  I am a student who is learning to code
# 83411                  I am a student who is learning to code
# 83418                          I am a developer by profession
#
#                      Employment Country US_State UK_Country  \
# ResponseId
# 28792        Employed full-time   India      NaN        NaN
# 12701        Employed full-time   India      NaN        NaN
# ...

# %%
filt = df1['Country'] == 'United States of America'
df1.loc[filt]['Age1stCode'].value_counts()
# Out:
# 11 - 17 years           7995
# 5 - 10 years            3169
# 18 - 24 years           2776
# 25 - 34 years            739
# 35 - 44 years            223
# Younger than 5 years     156
# 45 - 54 years            107
# 55 - 64 years             67
# Older than 64 years       18
# Name: Age1stCode, dtype: int64

# %%
country_grp['MainBranch'].value_counts().head(50
                                             )
# Out:
# Country      MainBranch
# Afghanistan  I am a developer by profession                                                     27
#              I am a student who is learning to code                                             15
#              None of these                                                                      11
#              I code primarily as a hobby                                                         9
#              I am not primarily a developer, but I write code sometimes as part of my work       3
# Albania      I am a developer by profession                                                     52
#              I am a student who is learning to code                                             17
#              I am not primarily a developer, but I write code sometimes as part of my work       4
# Algeria      I am a developer by profession                                                     27
# ...

# %%
country_grp['MainBranch'].value_counts().loc['China']
# Out:
# MainBranch
# I am a developer by profession                                                   638
# I am a student who is learning to code                                           252
# I am not primarily a developer, but I write code sometimes as part of my work     87
# I code primarily as a hobby                                                       54
# I used to be a developer by profession, but no longer am                          14
# None of these                                                                     10
# Name: MainBranch, dtype: int64

# %%
country_grp['SalaryUSD'].median().loc['India']
# Out:
# 14748.0

# %%
country_grp['SalaryUSD'].agg(['median','mean'])
# Out:
#                                        median          mean
# Country
# Afghanistan                            9792.0  2.794748e+06
# Albania                               15900.0  4.499814e+04
# Algeria                                9875.0  1.446114e+04
# Andorra                               94045.5  8.928200e+04
# Angola                                 9750.0  2.155680e+04
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  2.246505e+04
# Viet Nam                              12678.0  1.995289e+04
# Yemen                                  3954.0  5.628667e+03
# Zambia                                 9816.0  1.991491e+04
# Zimbabwe                               7200.0  1.141477e+04
#
# [181 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['median','mean']).loc['India']
# Out:
# median    14748.000000
# mean      42522.583464
# Name: India, dtype: float64

# %%
filt = df1['Country'] == 'United States of America'
df1.loc[filt]['SurveyEase'].str.contains("Easy").sum()
# Out:
# 12218

# %%
country_grp['SurveyEase'].apply(lambda x: x.str.contains("Easy").sum())
# Out:
# Country
# Afghanistan                              24
# Albania                                  48
# Algeria                                  31
# Andorra                                   5
# Angola                                   11
#                                        ...
# Venezuela, Bolivarian Republic of...     86
# Viet Nam                                219
# Yemen                                    13
# Zambia                                   16
# Zimbabwe                                 20
# Name: SurveyEase, Length: 181, dtype: int64

# %%
country_respomdents = df1['Country'].value_counts()
country_respomdents
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Papua New Guinea                                            1
# Dominica                                                    1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Name: Country, Length: 181, dtype: int64

# %%
easy = country_grp['SurveyEase'].apply(lambda x: x.str.contains("Easy"))

# %%
easy
# Out:
# ResponseId
# 65400    False
# 22667     True
# 27199    False
# 31087    False
# 44641    False
#          ...
# 75694    False
# 76083     True
# 79302      NaN
# 80997     True
# 82407    False
# Name: SurveyEase, Length: 83439, dtype: object

# %%
data_df = pd.concat([easy,country_respomdents],axis='columns',sort = False)

# %%
data_df
# Out:
#                                      SurveyEase  Country
# 1                                          True      NaN
# 2                                          True      NaN
# 3                                          True      NaN
# 4                                         False      NaN
# 5                                          True      NaN
# ...                                         ...      ...
# Venezuela, Bolivarian Republic of...        NaN    104.0
# Viet Nam                                    NaN    386.0
# Yemen                                       NaN     20.0
# Zambia                                      NaN     22.0
# Zimbabwe                                    NaN     36.0
#
# [83620 rows x 2 columns]

# %%
data_df.rename(columns = {"country":"no of easy", "SurveyEase": "easy"},inplace=True)

# %%
data_df
# Out:
#                                        easy  Country
# 1                                      True      NaN
# 2                                      True      NaN
# 3                                      True      NaN
# 4                                     False      NaN
# 5                                      True      NaN
# ...                                     ...      ...
# Venezuela, Bolivarian Republic of...    NaN    104.0
# Viet Nam                                NaN    386.0
# Yemen                                   NaN     20.0
# Zambia                                  NaN     22.0
# Zimbabwe                                NaN     36.0
#
# [83620 rows x 2 columns]

# %% [markdown]
# ## Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)

df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df.dropna(axis='index',how='all')
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
df.dropna(axis='columns',how='all')
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dropna(axis='columns',how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df.dropna(axis='index',how='all', subset=['email'])
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 5   None      NaN      Anonymous@email.com  None

# %%
df.dropna(axis='index',how='all', subset=['last','email'])
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df = pd.DataFrame(people)

df.replace('NA',np.nan,inplace=True)
df.replace('Missing',np.nan,inplace=True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dropna(axis='index',how='all', subset=['last','email'])
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('0')
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
#df['age'].mean()

# %%
type(np.nan)
# Out:
# float

# %%
df['age'] =df['age'].astype(float)

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# 46.75

# %% [markdown]
# ## Now working the stack overflow dataset

# %%
df1
# Out:
#                                         MainBranch  \
# ResponseId
# 65400               I am a developer by profession
# 22667               I am a developer by profession
# 27199               I am a developer by profession
# 31087               I am a developer by profession
# 44641               I am a developer by profession
# ...                                            ...
# 75694       I am a student who is learning to code
# 76083               I am a developer by profession
# 79302       I am a student who is learning to code
# 80997                  I code primarily as a hobby
# 82407       I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 65400                                      Employed full-time  Afghanistan
# 22667       Independent contractor, freelancer, or self-em...  Afghanistan
# 27199       Independent contractor, freelancer, or self-em...  Afghanistan
# ...

# %%
na_vals = ['NA', 'Missing']

# %%
df1
# Out:
#                                         MainBranch  \
# ResponseId
# 65400               I am a developer by profession
# 22667               I am a developer by profession
# 27199               I am a developer by profession
# 31087               I am a developer by profession
# 44641               I am a developer by profession
# ...                                            ...
# 75694       I am a student who is learning to code
# 76083               I am a developer by profession
# 79302       I am a student who is learning to code
# 80997                  I code primarily as a hobby
# 82407       I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 65400                                      Employed full-time  Afghanistan
# 22667       Independent contractor, freelancer, or self-em...  Afghanistan
# 27199       Independent contractor, freelancer, or self-em...  Afghanistan
# ...

# %%
#df1['YearsCode'].mean()

# %%
df1['YearsCode'].unique()
# Out:
# array(['7', '5', '3', '16', '8', 'Less than 1 year', '6', '4', nan, '2',
#        '10', '9', '11', 'More than 50 years', '32', '1', '20', '23', '12',
#        '13', '25', '30', '15', '18', '46', '14', '17', '37', '28', '40',
#        '35', '26', '38', '19', '22', '21', '33', '31', '36', '24', '34',
#        '27', '41', '43', '50', '29', '45', '42', '48', '39', '47', '49',
#        '44'], dtype=object)

# %%
df1['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
df1['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df1['YearsCode'].unique()
# Out:
# array(['7', '5', '3', '16', '8', 0, '6', '4', nan, '2', '10', '9', '11',
#        51, '32', '1', '20', '23', '12', '13', '25', '30', '15', '18',
#        '46', '14', '17', '37', '28', '40', '35', '26', '38', '19', '22',
#        '21', '33', '31', '36', '24', '34', '27', '41', '43', '50', '29',
#        '45', '42', '48', '39', '47', '49', '44'], dtype=object)

# %%
df1['YearsCode'] = df1['YearsCode'].astype(float)

# %%
df1['YearsCode'].mean()
# Out:
# 12.338200169032717

# %%
df1['YearsCode'].median()
# Out:
# 10.0

# %% [markdown]
# ## Working with Dates and Time Series Data

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y=%m-%d %I-%p')

df2 = pd.read_csv("/Users/narenderbeniwal/Downloads/ETH_1H.csv", date_parser=d_parser)
pd.set_option("display.max_columns", None)

# %%
df2
# Out:
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                  ...     ...     ...     ...     ...
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume
# 0      150.39   650.188125
# ...

# %%
df2.shape
# Out:
# (34497, 8)

# %%
df2.loc[0,'Date']
# Out:
# '2020-04-16 00:00:00'

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume
# 0      150.39   650.188125
# ...

# %%
df2['Date'] = pd.to_datetime(df2['Date'], format='%Y=%m-%d %I-%p')

# %%
df2['Date']
# Out:
# 0       2020-04-16 00:00:00
# 1       2020-04-15 23:00:00
# 2       2020-04-15 22:00:00
# 3       2020-04-15 21:00:00
# 4       2020-04-15 20:00:00
#                 ...
# 34492   2016-05-09 17:00:00
# 34493   2016-05-09 16:00:00
# 34494   2016-05-09 15:00:00
# 34495   2016-05-09 14:00:00
# 34496   2016-05-09 13:00:00
# Name: Date, Length: 34497, dtype: datetime64[ns]

# %%
df2
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume
# 0      150.39   650.188125
# ...

# %%
df2.loc[0,'Date'].day_name()
# Out:
# 'Thursday'

# %%
df2['Date'].dt.day_name()
# Out:
# 0         Thursday
# 1        Wednesday
# 2        Wednesday
# 3        Wednesday
# 4        Wednesday
#            ...
# 34492       Monday
# 34493       Monday
# 34494       Monday
# 34495       Monday
# 34496       Monday
# Name: Date, Length: 34497, dtype: object

# %%
df2['Day of week'] = df2['Date'].dt.day_name()

# %%
df2
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume Day of week
# 0      150.39   650.188125    Thursday
# ...

# %%
df2['Date'].min()
# Out:
# Timestamp('2016-05-09 13:00:00')

# %%
df2['Date'].max()
# Out:
# Timestamp('2020-04-16 00:00:00')

# %%
 df2['Date'].max() - df2['Date'].min()
# Out:
# Timedelta('1437 days 11:00:00')

# %%
filt = (df2['Date']<'2020')

# %%
df2.loc[filt]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 2545    1577833200000 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82
# 2546    1577829600000 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77
# 2547    1577826000000 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81
# 2548    1577822400000 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86
# 2549    1577818800000 2019-12-31 19:00:00  ETHUSD  128.78  128.78  127.86
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume Day of week
# 2545   128.84   857.650259     Tuesday
# ...

# %%
filt1 = (df2['Date']>=pd.to_datetime('2019-01-01')) & (df2['Date']<pd.to_datetime('2020-01-01'))

# %%
df2.loc[filt1]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 2545    1577833200000 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82
# 2546    1577829600000 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77
# 2547    1577826000000 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81
# 2548    1577822400000 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86
# 2549    1577818800000 2019-12-31 19:00:00  ETHUSD  128.78  128.78  127.86
# ...               ...                 ...     ...     ...     ...     ...
# 11297   1546315200000 2019-01-01 04:00:00  ETHUSD  130.83  133.75  130.83
# 11298   1546311600000 2019-01-01 03:00:00  ETHUSD  129.79  131.00  129.79
# 11299   1546308000000 2019-01-01 02:00:00  ETHUSD  130.98  130.98  129.25
# 11300   1546304400000 2019-01-01 01:00:00  ETHUSD  131.10  131.10  128.72
# 11301   1546300800000 2019-01-01 00:00:00  ETHUSD  130.80  131.70  130.00
#
#         Close       Volume Day of week
# 2545   128.84   857.650259     Tuesday
# ...

# %%
df2.set_index('Date', inplace=True)

# %%
df2
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-04-16 00:00:00   1586995200000  ETHUSD  152.94  152.94  150.39  150.39
# 2020-04-15 23:00:00   1586991600000  ETHUSD  155.81  155.81  151.39  152.94
# 2020-04-15 22:00:00   1586988000000  ETHUSD  157.18  157.30  155.32  155.81
# 2020-04-15 21:00:00   1586984400000  ETHUSD  158.04  158.31  157.16  157.18
# 2020-04-15 20:00:00   1586980800000  ETHUSD  157.10  158.10  156.87  158.04
# ...                             ...     ...     ...     ...     ...     ...
# 2016-05-09 17:00:00      1462813200  ETHUSD    9.83    9.83    9.48    9.49
# 2016-05-09 16:00:00      1462809600  ETHUSD    9.99    9.99    9.79    9.83
# 2016-05-09 15:00:00      1462806000  ETHUSD   10.00   10.00    9.99    9.99
# 2016-05-09 14:00:00      1462802400  ETHUSD    9.55   10.00    9.55   10.00
# 2016-05-09 13:00:00      1462798800  ETHUSD    0.00   12.00    0.00    9.55
#
#                           Volume Day of week
# ...

# %%
df2['2019']
# Out:
# /var/folders/12/9_hj00mj65v4tgx35t4t6c280000gn/T/ipykernel_1909/735323592.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df2['2019']
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2019-12-31 23:00:00   1577833200000  ETHUSD  128.68  128.85  127.82  128.84
# 2019-12-31 22:00:00   1577829600000  ETHUSD  128.40  128.93  127.77  128.68
# 2019-12-31 21:00:00   1577826000000  ETHUSD  127.87  128.41  127.81  128.40
# 2019-12-31 20:00:00   1577822400000  ETHUSD  127.86  128.30  127.86  127.87
# 2019-12-31 19:00:00   1577818800000  ETHUSD  128.78  128.78  127.86  127.86
# ...                             ...     ...     ...     ...     ...     ...
# 2019-01-01 04:00:00   1546315200000  ETHUSD  130.83  133.75  130.83  132.09
# ...

# %%
df2['2020-01':'2020-03']
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-03-01 00:00:00   1583020800000  ETHUSD  217.35  221.00  216.62  218.09
# 2020-02-29 23:00:00   1583017200000  ETHUSD  222.93  223.96  217.26  217.35
# 2020-02-29 22:00:00   1583013600000  ETHUSD  223.59  223.76  222.32  222.93
# 2020-02-29 21:00:00   1583010000000  ETHUSD  224.81  225.08  223.05  223.59
# 2020-02-29 20:00:00   1583006400000  ETHUSD  225.56  225.56  223.55  224.81
# ...                             ...     ...     ...     ...     ...     ...
# 2020-02-01 04:00:00   1580529600000  ETHUSD  182.65  183.42  181.86  182.03
# 2020-02-01 03:00:00   1580526000000  ETHUSD  183.20  183.51  182.63  182.65
# 2020-02-01 02:00:00   1580522400000  ETHUSD  183.21  184.05  182.98  183.20
# 2020-02-01 01:00:00   1580518800000  ETHUSD  181.20  183.38  181.08  183.21
# 2020-02-01 00:00:00   1580515200000  ETHUSD  179.75  181.20  179.15  181.20
#
#                           Volume Day of week
# ...

# %%
df2['2020-01':'2020-03']['Close'].mean()
# Out:
# 238.04850789096147

# %%
df2['2020-01':'2020-03'].head(20)
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-03-01 00:00:00   1583020800000  ETHUSD  217.35  221.00  216.62  218.09
# 2020-02-29 23:00:00   1583017200000  ETHUSD  222.93  223.96  217.26  217.35
# 2020-02-29 22:00:00   1583013600000  ETHUSD  223.59  223.76  222.32  222.93
# 2020-02-29 21:00:00   1583010000000  ETHUSD  224.81  225.08  223.05  223.59
# 2020-02-29 20:00:00   1583006400000  ETHUSD  225.56  225.56  223.55  224.81
# 2020-02-29 19:00:00   1583002800000  ETHUSD  225.05  225.92  224.06  225.56
# 2020-02-29 18:00:00   1582999200000  ETHUSD  225.37  225.99  224.65  225.05
# 2020-02-29 17:00:00   1582995600000  ETHUSD  222.94  225.39  222.27  225.37
# 2020-02-29 16:00:00   1582992000000  ETHUSD  225.43  226.06  222.43  222.94
# 2020-02-29 15:00:00   1582988400000  ETHUSD  223.31  226.04  221.66  225.43
# 2020-02-29 14:00:00   1582984800000  ETHUSD  224.32  224.32  221.17  223.31
# ...

# %%
df2['2020-01':'2020-03'].max()
# Out:
# Unix Timestamp    1583020800000
# Symbol                   ETHUSD
# Open                     286.48
# High                     289.58
# Low                      285.29
# Close                    286.48
# Volume             14699.656142
# Day of week           Wednesday
# dtype: object

# %%
df2['High']
# Out:
# Date
# 2020-04-16 00:00:00    152.94
# 2020-04-15 23:00:00    155.81
# 2020-04-15 22:00:00    157.30
# 2020-04-15 21:00:00    158.31
# 2020-04-15 20:00:00    158.10
#                         ...
# 2016-05-09 17:00:00      9.83
# 2016-05-09 16:00:00      9.99
# 2016-05-09 15:00:00     10.00
# 2016-05-09 14:00:00     10.00
# 2016-05-09 13:00:00     12.00
# Name: High, Length: 34497, dtype: float64

# %%
df2['High'].resample('D').max()
# Out:
# Date
# 2016-05-09     12.00
# 2016-05-10      9.96
# 2016-05-11     10.47
# 2016-05-12     12.00
# 2016-05-13     11.59
#                ...
# 2020-04-12    165.37
# 2020-04-13    159.51
# 2020-04-14    162.15
# 2020-04-15    161.52
# 2020-04-16    152.94
# Freq: D, Name: High, Length: 1439, dtype: float64

# %%
# %matplotlib inline

# %%
df2['High']
# Out:
# Date
# 2020-04-16 00:00:00    152.94
# 2020-04-15 23:00:00    155.81
# 2020-04-15 22:00:00    157.30
# 2020-04-15 21:00:00    158.31
# 2020-04-15 20:00:00    158.10
#                         ...
# 2016-05-09 17:00:00      9.83
# 2016-05-09 16:00:00      9.99
# 2016-05-09 15:00:00     10.00
# 2016-05-09 14:00:00     10.00
# 2016-05-09 13:00:00     12.00
# Name: High, Length: 34497, dtype: float64

# %%
highs =df2['High'].resample('D').max()

# %%
highs
# Out:
# Date
# 2016-05-09     12.00
# 2016-05-10      9.96
# 2016-05-11     10.47
# 2016-05-12     12.00
# 2016-05-13     11.59
#                ...
# 2020-04-12    165.37
# 2020-04-13    159.51
# 2020-04-14    162.15
# 2020-04-15    161.52
# 2020-04-16    152.94
# Freq: D, Name: High, Length: 1439, dtype: float64

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df2.resample('W').mean()
# Out:
#             Unix Timestamp        Open        High         Low       Close  \
# Date
# 2016-05-15    1.463076e+09   10.140387   10.310516   10.052387   10.205290
# 2016-05-22    1.463657e+09   13.042262   13.144048   12.965179   13.066964
# 2016-05-29    1.464262e+09   12.481012   12.555536   12.385357   12.471012
# 2016-06-05    1.464867e+09   13.586369   13.651667   13.542202   13.594583
# 2016-06-12    1.465472e+09   14.287500   14.326190   14.260179   14.297798
# ...                    ...         ...         ...         ...         ...
# 2020-03-22    1.584617e+12  124.640952  126.387917  122.802262  124.636012
# 2020-03-29    1.585222e+12  133.274762  134.287857  132.255714  133.285893
# 2020-04-05    1.585827e+12  137.517083  138.314583  136.791310  137.627440
# 2020-04-12    1.586432e+12  163.601548  164.731071  162.422560  163.693929
# 2020-04-19    1.586866e+12  156.890137  157.744384  155.952055  156.778219
#
#                  Volume
# Date
# 2016-05-15    70.896402
# ...

# %%
df2.resample('W').agg({'Close':'mean','Low':'min','Volume':'sum'})
# Out:
#                  Close     Low         Volume
# Date
# 2016-05-15   10.205290    0.00   10988.942273
# 2016-05-22   13.066964   10.06   40673.495362
# 2016-05-29   12.471012   10.41   58051.809091
# 2016-06-05   13.594583   12.41   47351.544496
# 2016-06-12   14.297798   13.83   52002.171838
# ...                ...     ...            ...
# 2020-03-22  124.636012  100.70  439980.283707
# 2020-03-29  133.285893  119.17  230941.584515
# 2020-04-05  137.627440  124.09  151022.864981
# 2020-04-12  163.693929  142.87  204715.937994
# 2020-04-19  156.778219  150.12   50776.889638
#
# [206 rows x 3 columns]

# %% [markdown]
# ## Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %%
df1
# Out:
#                                         MainBranch  \
# ResponseId
# 65400               I am a developer by profession
# 22667               I am a developer by profession
# 27199               I am a developer by profession
# 31087               I am a developer by profession
# 44641               I am a developer by profession
# ...                                            ...
# 75694       I am a student who is learning to code
# 76083               I am a developer by profession
# 79302       I am a student who is learning to code
# 80997                  I code primarily as a hobby
# 82407       I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 65400                                      Employed full-time  Afghanistan
# 22667       Independent contractor, freelancer, or self-em...  Afghanistan
# 27199       Independent contractor, freelancer, or self-em...  Afghanistan
# ...

# %%
filt = (df1['Country'] == 'India')
india_df = df1.loc[filt]
india_df.head()
# Out:
#                                 MainBranch          Employment Country  \
# ResponseId
# 28792       I am a developer by profession  Employed full-time   India
# 12701       I am a developer by profession  Employed full-time   India
# 64388       I am a developer by profession  Employed full-time   India
# 12794       I am a developer by profession  Employed full-time   India
# 3641        I am a developer by profession  Employed full-time   India
#
#            US_State UK_Country  \
# ResponseId
# 28792           NaN        NaN
# 12701           NaN        NaN
# 64388           NaN        NaN
# 12794           NaN        NaN
# 3641            NaN        NaN
#
#                                                     EdLevel     Age1stCode  \
# ResponseId
# 28792          Bachelor’s degree (B.A., B.S., B.Eng., etc.)  35 - 44 years
# 12701       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  25 - 34 years
# 64388          Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# ...

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_excel('modified.xlsx')

# %%
test = pd.read_excel('modified.xlsx', index_col='ResponseId')

# %%
test
# Out:
#                                                    MainBranch  \
# ResponseId
# 28792                          I am a developer by profession
# 12701                          I am a developer by profession
# 64388                          I am a developer by profession
# 12794                          I am a developer by profession
# 3641                           I am a developer by profession
# ...                                                       ...
# 83387                          I am a developer by profession
# 83398       I used to be a developer by profession, but no...
# 83407                  I am a student who is learning to code
# 83411                  I am a student who is learning to code
# 83418                          I am a developer by profession
#
#                      Employment Country  US_State  UK_Country  \
# ResponseId
# 28792        Employed full-time   India       NaN         NaN
# 12701        Employed full-time   India       NaN         NaN
# ...

# %%
test.head()
# Out:
#                                 MainBranch          Employment Country  \
# ResponseId
# 28792       I am a developer by profession  Employed full-time   India
# 12701       I am a developer by profession  Employed full-time   India
# 64388       I am a developer by profession  Employed full-time   India
# 12794       I am a developer by profession  Employed full-time   India
# 3641        I am a developer by profession  Employed full-time   India
#
#             US_State  UK_Country  \
# ResponseId
# 28792            NaN         NaN
# 12701            NaN         NaN
# 64388            NaN         NaN
# 12794            NaN         NaN
# 3641             NaN         NaN
#
#                                                     EdLevel     Age1stCode  \
# ResponseId
# 28792          Bachelor’s degree (B.A., B.S., B.Eng., etc.)  35 - 44 years
# 12701       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  25 - 34 years
# ...

# %%
india_df.to_json('modified.json', orient='records', lines=True)

# %%
test = pd.read_json('modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                        MainBranch          Employment Country  US_State  \
# 0  I am a developer by profession  Employed full-time   India       NaN
# 1  I am a developer by profession  Employed full-time   India       NaN
# 2  I am a developer by profession  Employed full-time   India       NaN
# 3  I am a developer by profession  Employed full-time   India       NaN
# 4  I am a developer by profession  Employed full-time   India       NaN
#
#    UK_Country                                          EdLevel     Age1stCode  \
# 0         NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  35 - 44 years
# 1         NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  25 - 34 years
# 2         NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3         NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 4         NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
conda install psycopg2
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/narenderbeniwal/Applications/anaconda3
#
#   added / updated specs:
#     - psycopg2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.9.24          |   py39hecd8cb5_0         155 KB
#     ------------------------------------------------------------
#                                            Total:         155 KB
#
# The following packages will be UPDATED:
#
#   certifi                          2022.9.14-py39hecd8cb5_0 --> 2022.9.24-py39hecd8cb5_0 None
#
#
#
# ...
# certifi-2022.9.24    | 155 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
#india_df.to_sql('sample_table', engine, if_exists='replace')

# %%
#sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')

# %%
#sql_df.head()

# %%
#sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')

# %%
#sql_df.head()

# %%
#posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
#posts_df.head()
